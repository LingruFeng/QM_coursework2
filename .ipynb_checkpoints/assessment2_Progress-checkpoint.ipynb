# %% [markdown]
# # QM assessment2 - code for Average Progress 8 score

# %% [markdown]
# ## import packages

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sms

# %% [markdown]
# ## read file

# %%
# Read csv file
df = pd.read_csv('gcse_results_clear.csv')

# %%
df.sample()
# Out:
#         code    area total_2016 total_2017 total_2018 total_2019  a8_2016  \
# 7  E09000009  Ealing      2,781      2,722      2,853      2,956     50.9
#
#    a8_2017  a8_2018  a8_2019  ...  girl_2018  girl_2019  a8_g_2016  a8_g_2017  \
# 7     48.7     50.0     50.9  ...      1,460      1,449       53.5       51.5
#
#   a8_g_2018 a8_g_2019 p8_g_2016 p8_g_2017  p8_g_2018  p8_g_2019
# 7      52.6      54.1      0.44      0.61       0.76       0.84
#
# [1 rows x 38 columns]

# %%
df.shape
# Out:
# (32, 38)

# %%
print(df.columns.values)
# Out:
# ['code' 'area' 'total_2016' 'total_2017' 'total_2018' 'total_2019'
#  'a8_2016' 'a8_2017' 'a8_2018' 'a8_2019' 'p8_2016' 'p8_2017' 'p8_2018'
#  'p8_2019' 'boy_2016' 'boy_2017' 'boy_2018' 'boy_2019' 'a8_b_2016'
#  'a8_b_2017' 'a8_b_2018' 'a8_b_2019' 'p8_b_2016' 'p8_b_2017' 'p8_b_2018'
#  'p8_b_2019' 'girl_2016' 'girl_2017' 'girl_2018' 'girl_2019' 'a8_g_2016'
#  'a8_g_2017' 'a8_g_2018' 'a8_g_2019' 'p8_g_2016' 'p8_g_2017' 'p8_g_2018'
#  'p8_g_2019']

# %% [markdown]
# ## Find the range of axes

# %%
print('boy progress max: ',max(max(df['p8_b_2016']),max(df['p8_b_2017']),max(df['p8_b_2018']),max(df['p8_b_2019'])))
print('boy progress min: ',min(min(df['p8_b_2016']),min(df['p8_b_2017']),min(df['p8_b_2018']),min(df['p8_b_2019'])))
print('girl progress max: ',max(max(df['p8_g_2016']),max(df['p8_g_2017']),max(df['p8_g_2018']),max(df['p8_g_2019'])))
print('girl progress min: ',min(min(df['p8_g_2016']),min(df['p8_g_2017']),min(df['p8_g_2018']),min(df['p8_g_2019'])))
# Out:
# boy progress max:  0.38
# boy progress min:  -0.49
# girl progress max:  0.84
# girl progress min:  -0.05

# %% [markdown]
# ## Boxplot the Average Progress 8 Score

# %%
plt.figure(dpi=120)
ax1 = plt.subplot(1,4,1)
ax2 = plt.subplot(1,4,2)
ax3 = plt.subplot(1,4,3)
ax4 = plt.subplot(1,4,4)

plt.sca(ax1)
plt.boxplot(df.p8_2016,widths=0.5)
plt.tick_params(labelsize=12)
plt.ylabel("Average Progress 8 score",fontsize=12)
plt.xticks([1],['2016'],fontsize=12)
plt.ylim([-0.3,0.6])

plt.sca(ax2)
plt.boxplot(df.p8_2017,widths=0.5)
plt.tick_params(labelsize=12)
plt.xticks([1],['2017'],fontsize=12)
plt.ylim([-0.3,0.6])

plt.sca(ax3)
plt.boxplot(df.p8_2018,widths=0.5)
plt.tick_params(labelsize=12)
plt.xticks([1],['2018'],fontsize=12)
plt.ylim([-0.3,0.6])

plt.sca(ax4)
plt.boxplot(df.p8_2019,widths=0.5)
plt.tick_params(labelsize=12)
plt.xticks([1],['2019'],fontsize=12)
plt.ylim([-0.3,0.6])

# And save the boxplot
plt.tight_layout()
plt.savefig('Progress_boxpolt')

# %% [markdown]
# ## Boxplot the Average Progress 8 Score grouped by gender and year

# %%
plt.figure(dpi=120)
ax1 = plt.subplot(1,4,1)
ax2 = plt.subplot(1,4,2)
ax3 = plt.subplot(1,4,3)
ax4 = plt.subplot(1,4,4)
df_2016=df['p8_b_2016'],df['p8_g_2016']
df_2017=df['p8_b_2017'],df['p8_g_2017']
df_2018=df['p8_b_2018'],df['p8_g_2018']
df_2019=df['p8_b_2019'],df['p8_g_2019']

plt.sca(ax1)
plt.boxplot(df_2016,widths=0.5)
plt.xticks([1,2], ["boy",'girl'],fontsize=12)
plt.tick_params(labelsize=12)
plt.ylabel("Average Progress 8 score",fontsize=12)
plt.title("2016",fontsize=12)
plt.ylim([-0.5,0.9])

plt.sca(ax2)
plt.boxplot(df_2017,widths=0.5)
plt.xticks([1,2], ["boy",'girl'],fontsize=12)
plt.tick_params(labelsize=12)
plt.title("2017",fontsize=12)
plt.ylim([-0.5,0.9])

plt.sca(ax3)
plt.boxplot(df_2018,widths=0.5)
plt.xticks([1,2], ["boy",'girl'],fontsize=12)
plt.tick_params(labelsize=12)
plt.title("2018",fontsize=12)
plt.ylim([-0.5,0.9])

plt.sca(ax4)
plt.boxplot(df_2019,widths=0.5)
plt.xticks([1,2], ["boy",'girl'],fontsize=12)
plt.tick_params(labelsize=12)
plt.title("2019",fontsize=12)
plt.ylim([-0.5,0.9])

# And save the boxplot
plt.tight_layout()
plt.savefig('Progress_gender_boxpolt')

# %% [markdown]
# ## scatter plot

# %%
fig, axes = plt.subplots(2,2,figsize=(14,3.6),dpi=120)
ax1 = plt.subplot(1,4,1)
ax2 = plt.subplot(1,4,2)
ax3 = plt.subplot(1,4,3)
ax4 = plt.subplot(1,4,4)
my_y_ticks = np.arange(-0.1, 0.9, 0.1)
my_x_ticks = np.arange(-0.5, 0.4, 0.2)

plt.sca(ax1)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.ylabel('Girl\'s Average Progress',fontsize=18)
plt.title('2016',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=15)
plt.plot(df['p8_b_2016'],df['p8_g_2016'],'b.',label='2016',markersize=10)

plt.sca(ax2)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.title('2017',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=15)
plt.plot(df['p8_b_2017'],df['p8_g_2017'],'g.',label='2016',markersize=10)

plt.sca(ax3)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.title('2018',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=15)
plt.plot(df['p8_b_2018'],df['p8_g_2018'],'y.',label='2016',markersize=10)

plt.sca(ax4)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.title('2019',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=15)
plt.plot(df['p8_b_2019'],df['p8_g_2019'],'c.',label='2016',markersize=10)
plt.suptitle('Boy\'s Average Progress',x=0.5,y=0,fontsize=18)
plt.tight_layout()

# And save the plot
plt.savefig('Progress_scatter_plot')

# %% [markdown]
# ## Caculate the Pearson Correlation Coefficient between girl and boy

# %%
r_2016 = np.corrcoef(df['p8_b_2016'], df['p8_g_2016'])
r_2017 = np.corrcoef(df['p8_b_2017'], df['p8_g_2017'])
r_2018 = np.corrcoef(df['p8_b_2018'], df['p8_g_2018'])
r_2019 = np.corrcoef(df['p8_b_2019'], df['p8_g_2019'])
print('2016:')
print('The Pearson Correlation Coefficient is:',round(r_2016[0][1],4))
print('2017:')
print('The Pearson Correlation Coefficient is:',round(r_2017[0][1],4))
print('2018:')
print('The Pearson Correlation Coefficient is:',round(r_2018[0][1],4))
print('2019:')
print('The Pearson Correlation Coefficient is:',round(r_2019[0][1],4))
# Out:
# 2016:
# The Pearson Correlation Coefficient is: 0.7852
# 2017:
# The Pearson Correlation Coefficient is: 0.8791
# 2018:
# The Pearson Correlation Coefficient is: 0.827
# 2019:
# The Pearson Correlation Coefficient is: 0.8709

# %% [markdown]
# ## Simple linear Regression

# %%
X_2016_boy = sms.add_constant(df['p8_b_2016'])
Y_2016_girl = df['p8_g_2016']
regression_model_a = sms.OLS(Y_2016_girl, X_2016_boy)
regression_model_b = regression_model_a.fit()
print(regression_model_b.summary())

X_2017_boy = sms.add_constant(df['p8_b_2017'])
Y_2017_girl = df['p8_g_2017']
regression_model_c = sms.OLS(Y_2017_girl, X_2017_boy)
regression_model_d = regression_model_c.fit()
print(regression_model_d.summary())

X_2018_boy = sms.add_constant(df['p8_b_2018'])
Y_2018_girl = df['p8_g_2018']
regression_model_e = sms.OLS(Y_2018_girl, X_2018_boy)
regression_model_f = regression_model_e.fit()
print(regression_model_f.summary())

X_2019_boy = sms.add_constant(df['p8_b_2019'])
Y_2019_girl = df['p8_g_2019']
regression_model_g = sms.OLS(Y_2019_girl, X_2019_boy)
regression_model_h = regression_model_g.fit()
print(regression_model_h.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              p8_g_2016   R-squared:                       0.617
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                     48.23
# Date:                Thu, 03 Dec 2020   Prob (F-statistic):           1.03e-07
# Time:                        17:56:56   Log-Likelihood:                 33.768
# No. Observations:                  32   AIC:                            -63.54
# Df Residuals:                      30   BIC:                            -60.60
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2887      0.016     18.445      0.000       0.257       0.321
# p8_b_2016      0.6842      0.099      6.945      0.000       0.483       0.885
# ==============================================================================
# Omnibus:                        0.454   Durbin-Watson:                   2.553
# Prob(Omnibus):                  0.797   Jarque-Bera (JB):                0.597
# Skew:                           0.190   Prob(JB):                        0.742
# Kurtosis:                       2.448   Cond. No.                         6.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              p8_g_2017   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     102.0
# Date:                Thu, 03 Dec 2020   Prob (F-statistic):           3.63e-11
# Time:                        17:56:56   Log-Likelihood:                 29.523
# No. Observations:                  32   AIC:                            -55.05
# Df Residuals:                      30   BIC:                            -52.12
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4159      0.018     23.532      0.000       0.380       0.452
# p8_b_2017      0.8232      0.082     10.100      0.000       0.657       0.990
# ==============================================================================
# Omnibus:                        3.281   Durbin-Watson:                   2.578
# Prob(Omnibus):                  0.194   Jarque-Bera (JB):                1.901
# Skew:                          -0.479   Prob(JB):                        0.387
# Kurtosis:                       3.714   Cond. No.                         4.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              p8_g_2018   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     64.91
# Date:                Thu, 03 Dec 2020   Prob (F-statistic):           5.41e-09
# Time:                        17:56:56   Log-Likelihood:                 19.691
# No. Observations:                  32   AIC:                            -35.38
# Df Residuals:                      30   BIC:                            -32.45
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4420      0.024     18.510      0.000       0.393       0.491
# p8_b_2018      0.8468      0.105      8.057      0.000       0.632       1.061
# ==============================================================================
# Omnibus:                        4.731   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                3.211
# Skew:                          -0.565   Prob(JB):                        0.201
# Kurtosis:                       4.064   Cond. No.                         4.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              p8_g_2019   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     94.18
# Date:                Thu, 03 Dec 2020   Prob (F-statistic):           9.16e-11
# Time:                        17:56:57   Log-Likelihood:                 25.967
# No. Observations:                  32   AIC:                            -47.93
# Df Residuals:                      30   BIC:                            -45.00
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5093      0.020     25.683      0.000       0.469       0.550
# p8_b_2019      0.8154      0.084      9.704      0.000       0.644       0.987
# ==============================================================================
# Omnibus:                        1.565   Durbin-Watson:                   2.268
# Prob(Omnibus):                  0.457   Jarque-Bera (JB):                1.271
# Skew:                           0.475   Prob(JB):                        0.530
# Kurtosis:                       2.778   Cond. No.                         4.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Statistics

# %%
print('2016:')
gradient_2016  = regression_model_b.params[1]
intercept_2016 = regression_model_b.params[0]
Rsquared_2016  = regression_model_b.rsquared
MSE_2016       = regression_model_b.mse_resid
pvalue_2016    = regression_model_b.f_pvalue
print("gradient  =", gradient_2016)
print("intercept =", intercept_2016)
print("Rsquared  =", Rsquared_2016)
print("MSE       =", MSE_2016)
print("pvalue    =", pvalue_2016)

print('2017:')
gradient_2017  = regression_model_d.params[1]
intercept_2017 = regression_model_d.params[0]
Rsquared_2017  = regression_model_d.rsquared
MSE_2017       = regression_model_d.mse_resid
pvalue_2017    = regression_model_d.f_pvalue
print("gradient  =", gradient_2017)
print("intercept =", intercept_2017)
print("Rsquared  =", Rsquared_2017)
print("MSE       =", MSE_2017)
print("pvalue    =", pvalue_2017)

print('2018:')
gradient_2018  = regression_model_f.params[1]
intercept_2018 = regression_model_f.params[0]
Rsquared_2018  = regression_model_f.rsquared
MSE_2018       = regression_model_f.mse_resid
pvalue_2018    = regression_model_f.f_pvalue
print("gradient  =", gradient_2018)
print("intercept =", intercept_2018)
print("Rsquared  =", Rsquared_2018)
print("MSE       =", MSE_2018)
print("pvalue    =", pvalue_2018)

print('2019:')
gradient_2019  = regression_model_h.params[1]
intercept_2019 = regression_model_h.params[0]
Rsquared_2019  = regression_model_h.rsquared
MSE_2019       = regression_model_h.mse_resid
pvalue_2019    = regression_model_h.f_pvalue
print("gradient  =", gradient_2019)
print("intercept =", intercept_2019)
print("Rsquared  =", Rsquared_2019)
print("MSE       =", MSE_2019)
print("pvalue    =", pvalue_2019)
# Out:
# 2016:
# gradient  = 0.6842282457525561
# intercept = 0.2887494739542211
# Rsquared  = 0.6165287862545147
# MSE       = 0.007568084017693843
# pvalue    = 1.0296434395107516e-07
# 2017:
# gradient  = 0.8232326101547985
# intercept = 0.41592644493680353
# Rsquared  = 0.7727424215679946
# MSE       = 0.009867145292886959
# pvalue    = 3.627520769276546e-11
# 2018:
# gradient  = 0.8468184080590614
# intercept = 0.441993323227334
# Rsquared  = 0.6839089877939144
# MSE       = 0.018242534246532136
# pvalue    = 5.412149636755255e-09
# 2019:
# gradient  = 0.8153792721941054
# intercept = 0.5093363564591118
# Rsquared  = 0.7584075780998072
# MSE       = 0.012323000294196803
# pvalue    = 9.158659125036752e-11

# %% [markdown]
# ### Plot the regression

# %%
fig, axes = plt.subplots(2,2,figsize=(14,3.6),dpi=120)
ax1 = plt.subplot(1,4,1)
ax2 = plt.subplot(1,4,2)
ax3 = plt.subplot(1,4,3)
ax4 = plt.subplot(1,4,4)

plt.sca(ax1)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.ylabel('Girl\'s Average Progress',fontsize=18)
plt.title('2016',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=18)
x_lobf = [min(df['p8_b_2016']),max(df['p8_b_2016'])]
y_lobf = [x_lobf[0]*gradient_2016 + intercept_2016,x_lobf[1]*gradient_2016 + intercept_2016]
plt.plot(df['p8_b_2016'],df['p8_g_2016'],'b.',label='2016',markersize=10)
plt.plot(x_lobf,y_lobf,'r--')

plt.sca(ax2)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.title('2017',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=18)
x_lobf = [min(df['p8_b_2017']),max(df['p8_b_2017'])]
y_lobf = [x_lobf[0]*gradient_2017 + intercept_2017,x_lobf[1]*gradient_2017 + intercept_2017]
plt.plot(df['p8_b_2017'],df['p8_g_2017'],'g.',label='2017',markersize=10)
plt.plot(x_lobf,y_lobf,'r--')

plt.sca(ax3)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.title('2018',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=18)
x_lobf = [min(df['p8_b_2018']),max(df['p8_b_2018'])]
y_lobf = [x_lobf[0]*gradient_2018 + intercept_2018,x_lobf[1]*gradient_2018 + intercept_2018]
plt.plot(df['p8_b_2018'],df['p8_g_2018'],'y.',label='2018',markersize=10)
plt.plot(x_lobf,y_lobf,'r--')

plt.sca(ax4)
plt.ylim([-0.1, 0.9])
plt.xlim([-0.5, 0.4])
plt.title('2019',fontsize=18)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.tick_params(labelsize=18)
x_lobf = [min(df['p8_b_2019']),max(df['p8_b_2019'])]
y_lobf = [x_lobf[0]*gradient_2019 + intercept_2019,x_lobf[1]*gradient_2019 + intercept_2019]
plt.plot(df['p8_b_2019'],df['p8_g_2019'],'c.',label='2019',markersize=10)
plt.plot(x_lobf,y_lobf,'r--')
plt.suptitle('Boy\'s Average Progress',x=0.5,y=0,fontsize=18)
plt.tight_layout()

# Save the regression plot
plt.savefig('Progress_regression_figure')

# %% [markdown]
# ### Residuals vs Fits Plot

# %%
fig, axes = plt.subplots(2,2,figsize=(14,3),dpi=120)
ax1 = plt.subplot(1,4,1)
ax2 = plt.subplot(1,4,2)
ax3 = plt.subplot(1,4,3)
ax4 = plt.subplot(1,4,4)
my_y_ticks = np.arange(-0.3, 0.4, 0.2)

plt.sca(ax1)
plt.xlim([-0.5, 0.4])
plt.ylim([-0.3,0.3])
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.title('2016',fontsize=18)
plt.ylabel('Residual',fontsize=18)
x_lobf = [-0.5, 0.4]
y_lobf = [0,0]
plt.tick_params(labelsize=15)
df['2016_residual'] = df['p8_g_2016'] - (df['p8_b_2016']*gradient_2016 + intercept_2016)
plt.plot(df['p8_b_2016'],df['2016_residual'],'b.',x_lobf,y_lobf,'r--')

plt.sca(ax2)
plt.xlim([-0.5, 0.4])
plt.ylim([-0.3,0.3])
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.title('2017',fontsize=18)
x_lobf = [-0.5, 0.4]
y_lobf = [0,0]
plt.tick_params(labelsize=15)
df['2017_residual'] = df['p8_g_2017'] - (df['p8_b_2017']*gradient_2017 + intercept_2017)
plt.plot(df['p8_b_2017'],df['2017_residual'],'g.',x_lobf,y_lobf,'r--')

plt.sca(ax3)
plt.xlim([-0.5, 0.4])
plt.ylim([-0.3,0.3])
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.title('2018',fontsize=18)
x_lobf = [-0.5, 0.4]
y_lobf = [0,0]
plt.tick_params(labelsize=15)
df['2018_residual'] = df['p8_g_2018'] - (df['p8_b_2018']*gradient_2018 + intercept_2018)
plt.plot(df['p8_b_2018'],df['2018_residual'],'y.',x_lobf,y_lobf,'r--')

plt.sca(ax4)
plt.xlim([-0.5, 0.4])
plt.ylim([-0.3,0.3])
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)
plt.title('2019',fontsize=18)
x_lobf = [-0.5, 0.4]
y_lobf = [0,0]
plt.tick_params(labelsize=15)
df['2019_residual'] = df['p8_g_2019'] - (df['p8_b_2019']*gradient_2019 + intercept_2019)
plt.plot(df['p8_b_2019'],df['2019_residual'],'c.',x_lobf,y_lobf,'r--')
plt.suptitle('Boy\'s Average Progress',x=0.5,y=0,fontsize=18)
plt.tight_layout()

# Save the regression plot
plt.savefig('Progress_regression_residual')

# %% [markdown]
# ### Plot residual density histogram and its kernel density curve

# %%
fig, axes = plt.subplots(2,2,figsize=(14,3),dpi=120)
ax1 = plt.subplot(1,4,1)
ax2 = plt.subplot(1,4,2)
ax3 = plt.subplot(1,4,3)
ax4 = plt.subplot(1,4,4)
my_y_ticks_2 = np.arange(0, 8, 1)
bins = np.arange(-0.3,0.3,0.05)

plt.sca(ax1)
df['2016_residual'].plot(kind = 'hist', bins = bins, color = 'blue', edgecolor = 'black', density = True, alpha=0.75)
df['2016_residual'].plot(kind = 'kde', color = 'red')
plt.xticks(my_y_ticks)
plt.yticks(my_y_ticks_2)
plt.xlim([-0.3,0.3])
plt.ylabel('Density',fontsize=18)
plt.title('2016',fontsize=18)
plt.tick_params(labelsize=15)

plt.sca(ax2)
df['2017_residual'].plot(kind = 'hist', bins = bins, color = 'green', edgecolor = 'black', density = True, alpha=0.75)
df['2017_residual'].plot(kind = 'kde', color = 'red')
plt.xticks(my_y_ticks)
plt.yticks(my_y_ticks_2)
plt.ylabel(' ')
plt.xlim([-0.3,0.3])
plt.title('2017',fontsize=18)
plt.tick_params(labelsize=15)

plt.sca(ax3)
df['2018_residual'].plot(kind = 'hist', bins = bins, color = 'yellow', edgecolor = 'black', density = True, alpha=0.75)
df['2018_residual'].plot(kind = 'kde', color = 'red')
plt.xticks(my_y_ticks)
plt.yticks(my_y_ticks_2)
plt.ylabel(' ')
plt.xlim([-0.3,0.3])
plt.title('2018',fontsize=18)
plt.tick_params(labelsize=15)

plt.sca(ax4)
df['2019_residual'].plot(kind = 'hist', bins = bins, color = 'cyan', edgecolor = 'black', density = True, alpha=0.75)
df['2019_residual'].plot(kind = 'kde', color = 'red')
plt.xticks(my_y_ticks)
plt.yticks(my_y_ticks_2)
plt.ylabel(' ')
plt.xlim([-0.3,0.3])
plt.title('2019',fontsize=18)
plt.tick_params(labelsize=15)
plt.suptitle('Residual',x=0.5,y=0,fontsize=18)
plt.tight_layout()

# Save the regression plot
plt.savefig('Progress_regression_residual_histogram')
